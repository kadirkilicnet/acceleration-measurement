# %% [markdown]
# # Acceleration Measurement Experiment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Data Manipulation

# %%
text_data = pd.read_csv('data/110190704_Dataset1.txt') 
text_data # The dataset is a plain text file, it needs to be manipulated
# Out:
#                                            Time   t (s)  Output Voltage  \
# 0    1            0.0                  4.181392                     NaN
# 1    2            0.1                  0.313632                     NaN
# 2    3            0.2                 -3.774455                     NaN
# 3    4            0.3                 -0.852857                     NaN
# 4    5            0.4                  3.321652                     NaN
# ..                                          ...                     ...
# 195  196         19.5                 -0.000247                     NaN
# 196  197         19.6                 -0.000588                     NaN
# 197  198         19.7                  0.000138                     NaN
# 198  199         19.8                  0.000558                     NaN
# 199  200         19.9                 -0.000042                     NaN
#
#       Vout (V)
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...

# %%
# Separating the data into columns based on white spaces
data1 = pd.read_csv('data/110190704_Dataset1.txt', delim_whitespace=True)
data1
# Out:
#      Time,     t       (s)  Output  Voltage,  Vout  (V)
# 0        1   0.0  4.181392     NaN       NaN   NaN  NaN
# 1        2   0.1  0.313632     NaN       NaN   NaN  NaN
# 2        3   0.2 -3.774455     NaN       NaN   NaN  NaN
# 3        4   0.3 -0.852857     NaN       NaN   NaN  NaN
# 4        5   0.4  3.321652     NaN       NaN   NaN  NaN
# ..     ...   ...       ...     ...       ...   ...  ...
# 195    196  19.5 -0.000247     NaN       NaN   NaN  NaN
# 196    197  19.6 -0.000588     NaN       NaN   NaN  NaN
# 197    198  19.7  0.000138     NaN       NaN   NaN  NaN
# 198    199  19.8  0.000558     NaN       NaN   NaN  NaN
# 199    200  19.9 -0.000042     NaN       NaN   NaN  NaN
#
# [200 rows x 7 columns]

# %%
data1.drop(data1.columns[3:], axis=1, inplace=True) # Dropping blank columns
data1
# Out:
#      Time,     t       (s)
# 0        1   0.0  4.181392
# 1        2   0.1  0.313632
# 2        3   0.2 -3.774455
# 3        4   0.3 -0.852857
# 4        5   0.4  3.321652
# ..     ...   ...       ...
# 195    196  19.5 -0.000247
# 196    197  19.6 -0.000588
# 197    198  19.7  0.000138
# 198    199  19.8  0.000558
# 199    200  19.9 -0.000042
#
# [200 rows x 3 columns]

# %%
# Instead of using column names, generic expressions are used
data1.rename(columns={data1.columns[0]: 'attempt',data1.columns[1]: 'time_s',data1.columns[2]: 'voltage_v' }, inplace=True)

# %% [markdown]
# ### Dataset 1

# %%
data1 # The dataset is manipulated
# Out:
#      attempt  time_s  voltage_v
# 0          1     0.0   4.181392
# 1          2     0.1   0.313632
# 2          3     0.2  -3.774455
# 3          4     0.3  -0.852857
# 4          5     0.4   3.321652
# ..       ...     ...        ...
# 195      196    19.5  -0.000247
# 196      197    19.6  -0.000588
# 197      198    19.7   0.000138
# 198      199    19.8   0.000558
# 199      200    19.9  -0.000042
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(data1['time_s'], data1['voltage_v'])

# %% [markdown]
# #### Sampling Frequency $f_s=\frac{1}{\Delta t}$

# %%
fs_1 = 1/(data1.iloc[1,1]-data1.iloc[0,1]) # Sampling frequency in Hz
fs_1
# Out:
# 10.0

# %%
plt.plot(data1['time_s'][0:30], data1['voltage_v'][0:30],'o')
plt.plot(data1['time_s'][0:30], data1['voltage_v'][0:30])

for x,y in zip(data1['time_s'][0:30], data1['voltage_v'][0:30]):

    label = f"{x}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,6), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %%
data1.head(30)
# Out:
#     attempt  time_s  voltage_v
# 0         1     0.0   4.181392
# 1         2     0.1   0.313632
# 2         3     0.2  -3.774455
# 3         4     0.3  -0.852857
# 4         5     0.4   3.321652
# 5         6     0.5   1.277745
# 6         7     0.6  -2.844083
# 7         8     0.7  -1.594422
# 8         9     0.8   2.360111
# 9        10     0.9   1.811240
# 10       11     1.0  -1.885269
# 11       12     1.1  -1.938164
# 12       13     1.2   1.432256
# 13       14     1.3   1.986206
# 14       15     1.4  -1.011026
# 15       16     1.5  -1.966923
# 16       17     1.6   0.628943
# 17       18     1.7   1.891982
# 18       19     1.8  -0.290988
# 19       20     1.9  -1.772794
# 20       21     2.0  -0.000000
# 21       22     2.1   1.620212
# 22       23     2.2   0.243053
# 23       24     2.3  -1.444301
# 24       25     2.4  -0.438799
# 25       26     2.5   1.254166
# 26       27     2.6   0.589173
# 27       28     2.7  -1.057837
# 28       29     2.8  -0.697154
# ...

# %% [markdown]
# ### Natural Frequency for 1

# %%
t1 = [0,1.7,2.5]
nf1 = pd.DataFrame(t1)
nf1.rename(columns={nf1.columns[0]:'t1'}, inplace=True)
nf1['t2'] = [0.4, 2.1,2.9]
nf1['x1'] = [4.181392, 1.891982,1.254166]
nf1['x2'] = [3.321652, 1.620212,0.862208]
nf1['T'] = nf1['t2'] - nf1['t1']
nf1['delta'] = np.log(nf1['x1']/nf1['x2']) # np.log() stands for natural logarithm (ln)
nf1['zeta'] = nf1['delta']/(2*math.pi)
nf1['omega'] = nf1['delta']/(nf1['zeta']*nf1['T'])
nf1
# Out:
#     t1   t2        x1        x2    T     delta      zeta      omega
# 0  0.0  0.4  4.181392  3.321652  0.4  0.230182  0.036635  15.707963
# 1  1.7  2.1  1.891982  1.620212  0.4  0.155068  0.024680  15.707963
# 2  2.5  2.9  1.254166  0.862208  0.4  0.374730  0.059640  15.707963

# %% [markdown]
# ### Dataset 2

# %%
# The steps may be implemented to any dataset
data2 = pd.read_csv('data/110190704_Dataset2.txt', delim_whitespace=True)
data2.drop(data2.columns[3:], axis=1, inplace=True)
data2.rename(columns={data2.columns[0]: 'attempt',data2.columns[1]: 'time_s',data2.columns[2]: 'voltage_v' }, inplace=True)
data2
# Out:
#      attempt  time_s  voltage_v
# 0          1    0.00   4.181392
# 1          2    0.15  -2.419706
# 2          3    0.30  -0.852857
# 3          4    0.45   3.101206
# 4          5    0.60  -2.844083
# ..       ...     ...        ...
# 195      196   29.25  -0.000008
# 196      197   29.40   0.000003
# 197      198   29.55   0.000003
# 198      199   29.70  -0.000006
# 199      200   29.85   0.000005
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(data2['time_s'], data2['voltage_v'])

# %% [markdown]
# #### Sampling Frequency $f_s=\frac{1}{\Delta t}$

# %%
fs_2 = 1/(data2.iloc[1,1]-data2.iloc[0,1]) # Sampling frequency in Hz
fs_2
# Out:
# 6.666666666666667

# %%
plt.plot(data2['time_s'][0:30], data2['voltage_v'][0:30],'o')
plt.plot(data2['time_s'][0:30], data2['voltage_v'][0:30])

for x,y in zip(data2['time_s'][0:30], data2['voltage_v'][0:30]):

    label = f"{x}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,6), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %%
data2.head(30)
# Out:
#     attempt  time_s  voltage_v
# 0         1    0.00   4.181392
# 1         2    0.15  -2.419706
# 2         3    0.30  -0.852857
# 3         4    0.45   3.101206
# 4         5    0.60  -2.844083
# 5         6    0.75   0.582079
# 6         7    0.90   1.811240
# 7         8    1.05  -2.604844
# 8         9    1.20   1.432256
# 9        10    1.35   0.618246
# 10       11    1.50  -1.966923
# 11       12    1.65   1.736284
# 12       13    1.80  -0.290988
# 13       14    1.95  -1.180238
# 14       15    2.10   1.620212
# 15       16    2.25  -0.843989
# 16       17    2.40  -0.438799
# 17       18    2.55   1.245258
# 18       19    2.70  -1.057837
# 19       20    2.85   0.136306
# 20       21    3.00   0.766493
# 21       22    3.15  -1.006208
# 22       23    3.30   0.494856
# 23       24    3.45   0.306409
# 24       25    3.60  -0.786992
# 25       26    3.75   0.643125
# 26       27    3.90  -0.056725
# 27       28    4.05  -0.496256
# 28       29    4.20   0.623913
# ...

# %% [markdown]
# ### Natural Frequency for 2

# %%
t1 = [0,1.65,3.75]
nf2 = pd.DataFrame(t1)
nf2.rename(columns={nf2.columns[0]:'t1'}, inplace=True)
nf2['t2'] = [0.45, 2.1,4.2]
nf2['x1'] = [4.181392, 1.736284,0.643125]
nf2['x2'] = [3.101206, 1.620212,0.623913]
nf2['T'] = nf2['t2'] - nf2['t1']
nf2['delta'] = np.log(nf2['x1']/nf2['x2']) # np.log() stands for natural logarithm (ln)
nf2['zeta'] = nf2['delta']/(2*math.pi)
nf2['omega'] = nf2['delta']/(nf2['zeta']*nf2['T'])
nf2
# Out:
#      t1    t2        x1        x2     T     delta      zeta      omega
# 0  0.00  0.45  4.181392  3.101206  0.45  0.298853  0.047564  13.962634
# 1  1.65  2.10  1.736284  1.620212  0.45  0.069190  0.011012  13.962634
# 2  3.75  4.20  0.643125  0.623913  0.45  0.030328  0.004827  13.962634

# %% [markdown]
# ### Dataset 3

# %%
data3 = pd.read_csv('data/110190704_Dataset3.txt', delim_whitespace=True)
data3.drop(data3.columns[3:], axis=1, inplace=True)
data3.rename(columns={data3.columns[0]: 'attempt',data3.columns[1]: 'time_s',data3.columns[2]: 'voltage_v' }, inplace=True)
data3
# Out:
#      attempt  time_s  voltage_v
# 0          1     0.0   4.181392
# 1          2     0.2  -3.774455
# 2          3     0.4   3.321652
# 3          4     0.6  -2.844083
# 4          5     0.8   2.360111
# ..       ...     ...        ...
# 195      196    39.0  -0.000000
# 196      197    39.2   0.000000
# 197      198    39.4  -0.000000
# 198      199    39.6   0.000000
# 199      200    39.8  -0.000000
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(data3['time_s'], data3['voltage_v'])

# %% [markdown]
# #### Sampling Frequency $f_s=\frac{1}{\Delta t}$

# %%
fs_3 = 1/(data3.iloc[1,1]-data3.iloc[0,1]) # Sampling frequency in Hz
fs_3
# Out:
# 5.0

# %%
plt.plot(data3['time_s'][0:30], data3['voltage_v'][0:30],'o')
plt.plot(data3['time_s'][0:30], data3['voltage_v'][0:30])

for x,y in zip(data3['time_s'][0:30], data3['voltage_v'][0:30]):

    label = f"{x}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,6), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %%
data3.head(10)
# Out:
#    attempt  time_s  voltage_v
# 0        1     0.0   4.181392
# 1        2     0.2  -3.774455
# 2        3     0.4   3.321652
# 3        4     0.6  -2.844083
# 4        5     0.8   2.360111
# 5        6     1.0  -1.885269
# 6        7     1.2   1.432256
# 7        8     1.4  -1.011026
# 8        9     1.6   0.628943
# 9       10     1.8  -0.290988

# %% [markdown]
# ### Natural Frequency for 3

# %%
t1 = [0,0.8,0.6]
nf3 = pd.DataFrame(t1)
nf3.rename(columns={nf3.columns[0]:'t1'}, inplace=True)
nf3['t2'] = [0.4,1.2,1.0]
nf3['x1'] = [4.181392, 2.360111,-2.844083]
nf3['x2'] = [3.321652, 1.432256,-1885269]
nf3['T'] = nf3['t2'] - nf3['t1']
nf3['delta'] = np.log(nf3['x1']/nf3['x2']) # np.log() stands for natural logarithm (ln)
nf3['zeta'] = nf3['delta']/(2*math.pi)
nf3['omega'] = nf3['delta']/(nf3['zeta']*nf3['T'])
nf3
# Out:
#     t1   t2        x1            x2    T      delta      zeta      omega
# 0  0.0  0.4  4.181392  3.321652e+00  0.4   0.230182  0.036635  15.707963
# 1  0.8  1.2  2.360111  1.432256e+00  0.4   0.499458  0.079491  15.707963
# 2  0.6  1.0 -2.844083 -1.885269e+06  0.4 -13.404340 -2.133367  15.707963

# %% [markdown]
# ### Dataset 4

# %%
data4 = pd.read_csv('data/110190704_Dataset4.txt', delim_whitespace=True)
data4.drop(data4.columns[3:], axis=1, inplace=True)
data4.rename(columns={data4.columns[0]: 'attempt',data4.columns[1]: 'time_s',data4.columns[2]: 'voltage_v' }, inplace=True)
data4
# Out:
#      attempt  time_s  voltage_v
# 0          1    0.00   4.181392
# 1          2    0.25  -3.106770
# 2          3    0.50   1.277745
# 3          4    0.75   0.582079
# 4          5    1.00  -1.885269
# ..       ...     ...        ...
# 195      196   48.75   0.000000
# 196      197   49.00  -0.000000
# 197      198   49.25   0.000000
# 198      199   49.50  -0.000000
# 199      200   49.75   0.000000
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(data4['time_s'], data4['voltage_v'])

# %% [markdown]
# #### Sampling Frequency $f_s=\frac{1}{\Delta t}$

# %%
fs_4 = 1/(data4.iloc[1,1]-data4.iloc[0,1]) # Sampling frequency in Hz
fs_4
# Out:
# 4.0

# %%
plt.plot(data4['time_s'][0:30], data4['voltage_v'][0:30],'o')
plt.plot(data4['time_s'][0:30], data4['voltage_v'][0:30])

for x,y in zip(data4['time_s'][0:30], data4['voltage_v'][0:30]):

    label = f"{x}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,6), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %%
data4.head(15)
# Out:
#     attempt  time_s  voltage_v
# 0         1    0.00   4.181392
# 1         2    0.25  -3.106770
# 2         3    0.50   1.277745
# 3         4    0.75   0.582079
# 4         5    1.00  -1.885269
# 5         6    1.25   2.336706
# 6         7    1.50  -1.966923
# 7         8    1.75   1.056946
# 8         9    2.00  -0.000000
# 9        10    2.25  -0.843989
# 10       11    2.50   1.254166
# 11       12    2.75  -1.189749
# 12       13    3.00   0.766493
# 13       14    3.25  -0.188974
# 14       15    3.50  -0.331243

# %% [markdown]
# ### Natural Frequency for 4

# %%
t1 = [0,1.25,2.5]
nf4 = pd.DataFrame(t1)
nf4.rename(columns={nf4.columns[0]:'t1'}, inplace=True)
nf4['t2'] = [0.5,1.75,3]
nf4['x1'] = [4.181392, 2.336706,1.254166]
nf4['x2'] = [1.277745, 1.056946,0.766493]
nf4['T'] = nf4['t2'] - nf4['t1']
nf4['delta'] = np.log(nf4['x1']/nf4['x2']) # np.log() stands for natural logarithm (ln)
nf4['zeta'] = nf4['delta']/(2*math.pi)
nf4['omega'] = nf4['delta']/(nf4['zeta']*nf4['T'])
nf4
# Out:
#      t1    t2        x1        x2    T     delta      zeta      omega
# 0  0.00  0.50  4.181392  1.277745  0.5  1.185547  0.188686  12.566371
# 1  1.25  1.75  2.336706  1.056946  0.5  0.793359  0.126267  12.566371
# 2  2.50  3.00  1.254166  0.766493  0.5  0.492401  0.078368  12.566371

# %% [markdown]
# ### Dataset 5

# %%
data5 = pd.read_csv('data/110190704_Dataset5.txt', delim_whitespace=True)
data5.drop(data5.columns[3:], axis=1, inplace=True)
data5.rename(columns={data5.columns[0]: 'attempt',data5.columns[1]: 'time_s',data5.columns[2]: 'voltage_v' }, inplace=True)
data5.head(10)
# Out:
#    attempt  time_s  voltage_v
# 0        1     0.0   4.181392
# 1        2     1.0  -1.885269
# 2        3     2.0  -0.000000
# 3        4     3.0   0.766493
# 4        5     4.0  -0.691179
# 5        6     5.0   0.311633
# 6        7     6.0   0.000000
# 7        8     7.0  -0.126700
# 8        9     8.0   0.114251
# 9       10     9.0  -0.051513

# %%
plt.figure(figsize=(10, 5))
plt.plot(data5['time_s'], data5['voltage_v'])

# %% [markdown]
# #### Sampling Frequency $f_s=\frac{1}{\Delta t}$

# %%
fs_5 = 1/(data5.iloc[1,1]-data5.iloc[0,1]) # Sampling frequency in Hz
fs_5
# Out:
# 1.0

# %%
plt.plot(data5['time_s'][0:15], data5['voltage_v'][0:15],'o')
plt.plot(data5['time_s'][0:15], data5['voltage_v'][0:15])

for x,y in zip(data5['time_s'][0:15], data5['voltage_v'][0:15]):

    label = f"{x}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,6), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %%
data5.head(15)
# Out:
#     attempt  time_s  voltage_v
# 0         1     0.0   4.181392
# 1         2     1.0  -1.885269
# 2         3     2.0  -0.000000
# 3         4     3.0   0.766493
# 4         5     4.0  -0.691179
# 5         6     5.0   0.311633
# 6         7     6.0   0.000000
# 7         8     7.0  -0.126700
# 8         9     8.0   0.114251
# 9        10     9.0  -0.051513
# 10       11    10.0  -0.000000
# 11       12    11.0   0.020943
# 12       13    12.0  -0.018886
# 13       14    13.0   0.008515
# 14       15    14.0   0.000000

# %% [markdown]
# ### Natural Frequency for 5

# %%
t1 = [0,4,8]
nf5 = pd.DataFrame(t1)
nf5.rename(columns={nf5.columns[0]:'t1'}, inplace=True)
nf5['t2'] = [3,7,11]
nf5['x1'] = [4.181392, -0.691179,0.114251]
nf5['x2'] = [0.766493, -0.126700,0.020943]
nf5['T'] = nf5['t2'] - nf5['t1']
nf5['delta'] = np.log(nf5['x1']/nf5['x2']) # np.log() stands for natural logarithm (ln)
nf5['zeta'] = nf5['delta']/(2*math.pi)
nf5['omega'] = nf5['delta']/(nf5['zeta']*nf5['T'])
nf5
# Out:
#    t1  t2        x1        x2  T     delta      zeta     omega
# 0   0   3  4.181392  0.766493  3  1.696574  0.270018  2.094395
# 1   4   7 -0.691179 -0.126700  3  1.696577  0.270019  2.094395
# 2   8  11  0.114251  0.020943  3  1.696593  0.270021  2.094395

# %% [markdown]
# ## Total Natural Frequency Table

# %%
nf_total = nf1.append(nf2)
nf_total = nf_total.append(nf3)
nf_total = nf_total.append(nf4)
nf_total = nf_total.append(nf5)
nf_total['omega']= nf_total['omega']/(2*math.pi)
nf_total
# Out:
#      t1     t2        x1            x2     T      delta      zeta     omega
# 0  0.00   0.40  4.181392  3.321652e+00  0.40   0.230182  0.036635  2.500000
# 1  1.70   2.10  1.891982  1.620212e+00  0.40   0.155068  0.024680  2.500000
# 2  2.50   2.90  1.254166  8.622080e-01  0.40   0.374730  0.059640  2.500000
# 0  0.00   0.45  4.181392  3.101206e+00  0.45   0.298853  0.047564  2.222222
# 1  1.65   2.10  1.736284  1.620212e+00  0.45   0.069190  0.011012  2.222222
# 2  3.75   4.20  0.643125  6.239130e-01  0.45   0.030328  0.004827  2.222222
# 0  0.00   0.40  4.181392  3.321652e+00  0.40   0.230182  0.036635  2.500000
# 1  0.80   1.20  2.360111  1.432256e+00  0.40   0.499458  0.079491  2.500000
# 2  0.60   1.00 -2.844083 -1.885269e+06  0.40 -13.404340 -2.133367  2.500000
# 0  0.00   0.50  4.181392  1.277745e+00  0.50   1.185547  0.188686  2.000000
# 1  1.25   1.75  2.336706  1.056946e+00  0.50   0.793359  0.126267  2.000000
# ...

# %%
nf_total.to_excel('natural_frequency.xlsx') # writing excel file for the report

# %% [markdown]
# ## Nyquist Criterion

# %% [markdown]
# ### $f_{Nyquist} = \frac{f_s}{2}$

# %% [markdown]
# $\omega_n$ should be less than $f_{Nyquist}$ to satisfy the Nyquist Criterion. Otherwise the data do not present the nature of the frequency properly.

# %%
nyquist = [fs_1/2,fs_2/2,fs_3/2,fs_4/2,fs_5/2]
nyquist
# Out:
# [5.0, 3.3333333333333335, 2.5, 2.0, 0.5]

# %% [markdown]
# The 3rd and 4th data are eliminated due to the Nyquist Criterion.

# %%
nf = nf1.append(nf2)
nf = nf.append(nf5)
nf['omega']= nf['omega']/(2*math.pi)
nf
# Out:
#      t1     t2        x1        x2     T     delta      zeta     omega
# 0  0.00   0.40  4.181392  3.321652  0.40  0.230182  0.036635  2.500000
# 1  1.70   2.10  1.891982  1.620212  0.40  0.155068  0.024680  2.500000
# 2  2.50   2.90  1.254166  0.862208  0.40  0.374730  0.059640  2.500000
# 0  0.00   0.45  4.181392  3.101206  0.45  0.298853  0.047564  2.222222
# 1  1.65   2.10  1.736284  1.620212  0.45  0.069190  0.011012  2.222222
# 2  3.75   4.20  0.643125  0.623913  0.45  0.030328  0.004827  2.222222
# 0  0.00   3.00  4.181392  0.766493  3.00  1.696574  0.270018  0.333333
# 1  4.00   7.00 -0.691179 -0.126700  3.00  1.696577  0.270019  0.333333
# 2  8.00  11.00  0.114251  0.020943  3.00  1.696593  0.270021  0.333333

# %%
delta_f = [fs_1/200,fs_2/200,fs_3/200,fs_4/200,fs_5/200] # Frequency Resolution 
delta_f
# Out:
# [0.05, 0.03333333333333333, 0.025, 0.02, 0.005]

# %% [markdown]
# ## Chauvenet Criterion

# %%
n = 9 # number of samples
p = 1 - 1/(2*n)
value = p/2
round(value,5)
# Out:
# 0.47222

# %% [markdown]
# $\frac{d_{max}}{\sigma}$ is found from the normal error function integral table.

# %%
max_dev = 1.91 # dmax/sigma (maximum deviation)

# %%
omega_mean = nf['omega'].agg('mean') # Average of omega values
round(omega_mean,6)
# Out:
# 1.685185

# %%
chauvenet = pd.DataFrame(nf['omega'])
chauvenet['di']= chauvenet['omega'] - omega_mean
chauvenet['di^2'] = chauvenet['di']**2
chauvenet
# Out:
#       omega        di      di^2
# 0  2.500000  0.814815  0.663923
# 1  2.500000  0.814815  0.663923
# 2  2.500000  0.814815  0.663923
# 0  2.222222  0.537037  0.288409
# 1  2.222222  0.537037  0.288409
# 2  2.222222  0.537037  0.288409
# 0  0.333333 -1.351852  1.827503
# 1  0.333333 -1.351852  1.827503
# 2  0.333333 -1.351852  1.827503

# %%
di2_std = (np.sum(chauvenet['di^2'])/(n-1))**(1/2) # Standard Deviation (sigma)
round(di2_std,6)
# Out:
# 1.020999

# %%
chauvenet['di/sigma'] = np.abs(chauvenet['di'])/di2_std
chauvenet
# Out:
#       omega        di      di^2  di/sigma
# 0  2.500000  0.814815  0.663923  0.798057
# 1  2.500000  0.814815  0.663923  0.798057
# 2  2.500000  0.814815  0.663923  0.798057
# 0  2.222222  0.537037  0.288409  0.525992
# 1  2.222222  0.537037  0.288409  0.525992
# 2  2.222222  0.537037  0.288409  0.525992
# 0  0.333333 -1.351852  1.827503  1.324049
# 1  0.333333 -1.351852  1.827503  1.324049
# 2  0.333333 -1.351852  1.827503  1.324049

# %%
# ALthough it is obvious that there is no elimination, the code written down below may be used for bigger data
filt = chauvenet['di/sigma'] > max_dev 
eliminated = chauvenet.loc[filt, 'di/sigma']
eliminated # There is no elimination
# Out:
# Series([], Name: di/sigma, dtype: float64)
